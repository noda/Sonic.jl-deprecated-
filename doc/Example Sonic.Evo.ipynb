# %%
#!/usr/bin/python3

import base64
import datetime
import requests

class Client():
    def __init__(self, username, password, endpoint='https://evo.elvaco.se/api/v1', ):
        self.endpoint = endpoint
        self.username = username
        self.password = password

        self.bearer_token = None

    def _authenticate(self):
        """
        API uses Basic Authentication
        """

        headers = {
            'authorization': 'Basic {0}'.format(
                base64.b64encode("{0}:{1}".format(
                    self.username,
                    self.password
                ).encode('utf-8')).decode('utf-8')
            )
        }

        url = "{0}/authenticate".format(self.endpoint)
        r = requests.get(url, headers=headers)

        authentication_response = r.json()

        if authentication_response.get('status', 200) != 200:
            # Exception ? authentication_response.get('message', None)
            return false

        self.bearer_token = authentication_response.get('token', None)

        return True

    def do_request(self, url, **kwargs):
        """
        Request wrapper
        """
        if self.bearer_token is None:
            self._authenticate()

        headers = {
            'authorization': 'Bearer {0}'.format(self.bearer_token)
        }

        r = requests.get(url, headers=headers, params=kwargs)
        data = r.json() # no longer returns json?

        if data.get('status', 200) != 200:
            # Exception ? authentication_response.get('message', None)
            return false

        return data

    def summary(self, medium='District heating'): # does not work anymore; returns some HTML
        url = '{0}/summary'.format(self.endpoint)
        after = datetime.datetime.now().isoformat()
        before = datetime.datetime.now().isoformat()
        reply = self.do_request(url, after=after, before=before, medium=medium)
        return reply

    def meters(self, size=50, page=0, medium='District heating'):
        url = '{0}/meters'.format(self.endpoint)
        after = '2019-11-01' # datetime.datetime.now().isoformat()
        before = '2019-12-01' # datetime.datetime.now().isoformat()
        medium = medium

        reply = self.do_request(url, after=after, before=before, medium=medium, size=size, page=page)
        # reply = self.do_request(url, medium=medium, size=size, page=page)
        return reply
        # return {
        #     'meters': reply.get('content', []),
        #     'totalPages': reply.get('totalPages', 0),
        #     'totalElements': reply.get('totalElements', 0),
        # }

    def meter(self, uuid):
        url = '{0}/meters/{1}'.format(self.endpoint, uuid)
        reply = self.do_request(url)
        return reply

# %%
client = Client("jens.brage@noda.se", "bV6CDHnC&tMm")

# %%
client.meters()
# Out:
# {'content': [{'id': '21c6582b-802f-4bf8-96bc-4c87682a991e',
#    'facility': '121426',
#    'address': '42545',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'regementsgatan 4',
#     'zip': 'unknown'},
#    'medium': 'District heating',
#    'manufacturer': 'ELV',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '12133603',
#    'readIntervalMinutes': 60},
#   {'id': 'd77ec9e7-8481-41d8-8489-cd2a583e432e',
#    'facility': '121428',
#    'address': '40238',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'regementsgatan 8',
#     'zip': '352 36',
#     'position': {'latitude': 56.8776581827931,
#      'longitude': 14.7922234766242,
#      'confidence': 0.5}},
#    'medium': 'District heating',
#    'manufacturer': 'ELV',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '12101001',
#    'readIntervalMinutes': 1440},
#   {'id': 'beafe30f-3062-44cb-a3b2-2195f80a3b77',
#    'facility': '121429',
#    'address': '42869',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'regementsgatan 10',
#     'zip': '35236',
#     'position': {'latitude': 56.8779318801408,
#      'longitude': 14.7912423416422,
#      'confidence': 1.0}},
#    'medium': 'District heating',
#    'manufacturer': 'LUG',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '6023856',
#    'readIntervalMinutes': 60},
#   {'id': '62ed587a-42cd-4709-8304-00c45beae559',
#    'facility': '121430',
#    'address': '42548',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'storgatan 53',
#     'zip': 'unknown',
#     'position': {'latitude': 56.8789318963609,
#      'longitude': 14.7912423383654,
#      'confidence': 1.0}},
#    'medium': 'District heating',
#    'manufacturer': 'ELV',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '12133585',
#    'readIntervalMinutes': 60},
#   {'id': 'ff295896-d701-4f45-9794-f5faa48206fc',
#    'facility': '121431',
#    'address': '27366',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'storgatan 51',
#     'zip': '35236',
#     'position': {'latitude': 56.8789318966886,
#      'longitude': 14.7918242348851,
#      'confidence': 1.0}},
#    'medium': 'District heating',
#    'manufacturer': 'LUG',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '6024032',
#    'readIntervalMinutes': 60},
#   {'id': 'e4ccfb08-aac0-4c32-9342-121a8b8ca762',
#    'facility': '121432',
#    'address': '40660',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'storgatan 49',
#     'zip': 'unknown',
#     'position': {'latitude': 56.8789318971801,
#      'longitude': 14.7922423547494,
#      'confidence': 1.0}},
#    'medium': 'District heating',
#    'manufacturer': 'ELV',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '12110509',
#    'readIntervalMinutes': 60},
#   {'id': 'b8e09693-05e1-4b3f-8d80-858ef88dca94',
#    'facility': '121433',
#    'address': '40701',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'storgatan 47',
#     'zip': 'unknown',
#     'position': {'latitude': 56.8789318960332,
#      'longitude': 14.7922423609753,
#      'confidence': 1.0}},
#    'medium': 'District heating',
#    'manufacturer': 'ELV',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '12061734',
#    'readIntervalMinutes': 1440},
#   {'id': 'e300168e-5fa1-4477-924b-3a6a3f03c6d7',
#    'facility': '121434',
#    'address': '39555',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'oskarsgatan 5',
#     'zip': '352 36',
#     'position': {'latitude': 56.8778550766931,
#      'longitude': 14.7910737951242,
#      'confidence': 0.5}},
#    'medium': 'District heating',
#    'manufacturer': 'ELV',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '12048021',
#    'readIntervalMinutes': 1440},
#   {'id': 'd5c54372-3faf-4f98-a212-ccc59602d4f2',
#    'facility': '121435',
#    'address': '41355',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'oskarsgatan 3',
#     'zip': 'unknown',
#     'position': {'latitude': 56.8789318909542,
#      'longitude': 14.7912423382016,
#      'confidence': 1.0}},
#    'medium': 'District heating',
#    'manufacturer': 'ELV',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '12133359',
#    'readIntervalMinutes': 60},
#   {'id': '7f289ae0-df96-46b2-9373-da4663ddf70b',
#    'facility': '121436',
#    'address': '61948110',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'oskarsgatan 8',
#     'zip': '352 36',
#     'position': {'latitude': 56.8774149311931,
#      'longitude': 14.7909462439242,
#      'confidence': 0.5}},
#    'medium': 'District heating',
#    'manufacturer': 'DME',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '6113378',
#    'readIntervalMinutes': 60},
#   {'id': '1e17bd00-804a-4324-b557-a2141a68650c',
#    'facility': '121437',
#    'address': '40632',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'oskarsgatan 6',
#     'zip': 'unknown',
#     'position': {'latitude': 56.8779318873497,
#      'longitude': 14.7902423321395,
#      'confidence': 1.0}},
#    'medium': 'District heating',
#    'manufacturer': 'ELV',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '12112995',
#    'readIntervalMinutes': 60},
#   {'id': '645e5242-2067-4b3f-bf3c-88985954bfa6',
#    'facility': '121438',
#    'address': '40694',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'storgatan 55',
#     'zip': 'unknown',
#     'position': {'latitude': 56.8789318968524,
#      'longitude': 14.7902423309926,
#      'confidence': 1.0}},
#    'medium': 'District heating',
#    'manufacturer': 'ELV',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '12113027',
#    'readIntervalMinutes': 60},
#   {'id': '66397891-1fda-4287-87ad-1837175a55ec',
#    'facility': '121439',
#    'address': '40795',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'storgatan 57',
#     'zip': 'unknown',
#     'position': {'latitude': 56.8789318965248,
#      'longitude': 14.790242323456,
#      'confidence': 1.0}},
#    'medium': 'District heating',
#    'manufacturer': 'ELV',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '12112963',
#    'readIntervalMinutes': 60},
#   {'id': '3b1f5b3f-f775-4a7f-98a1-5e611b4c8964',
#    'facility': '121441',
#    'address': '40709',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'frejagatan 7',
#     'zip': 'unknown',
#     'position': {'latitude': 56.874931827712,
#      'longitude': 14.7972424366694,
#      'confidence': 1.0}},
#    'medium': 'District heating',
#    'manufacturer': 'LUG',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '6009329',
#    'readIntervalMinutes': 60},
#   {'id': '13c3ae2d-6c6c-43d3-830e-14087e28bb4e',
#    'facility': '121442',
#    'address': '30183',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'villagatan 9',
#     'zip': 'unknown',
#     'position': {'latitude': 56.8778993188746,
#      'longitude': 14.8206724282195,
#      'confidence': 0.0}},
#    'medium': 'District heating',
#    'manufacturer': 'LUG',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '6003894',
#    'readIntervalMinutes': 60},
#   {'id': '5cf41ddd-f4ca-42db-876c-95d4e1f6be4e',
#    'facility': '121443',
#    'address': '41987',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'villagatan 13',
#     'zip': 'unknown',
#     'position': {'latitude': 56.877931885056,
#      'longitude': 14.8212428429926,
#      'confidence': 1.0}},
#    'medium': 'District heating',
#    'manufacturer': 'LUG',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '6009619',
#    'readIntervalMinutes': 60},
#   {'id': 'f0e5b47b-7801-4b09-8859-c4d87fe7e035',
#    'facility': '121444',
#    'address': '38971',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'villagatan 15',
#     'zip': '35240',
#     'position': {'latitude': 56.8779318845644,
#      'longitude': 14.822524285184,
#      'confidence': 1.0}},
#    'medium': 'District heating',
#    'manufacturer': 'ELV',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '12027817',
#    'readIntervalMinutes': 1440},
#   {'id': '0016a5f0-ff31-4dda-9465-0aaf841ce2dd',
#    'facility': '121445',
#    'address': '30550',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'villagatan 4 a',
#     'zip': 'unknown',
#     'position': {'latitude': 56.8779318847283,
#      'longitude': 14.8182427938406,
#      'confidence': 1.0}},
#    'medium': 'District heating',
#    'manufacturer': 'LUG',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '6015200',
#    'readIntervalMinutes': 60},
#   {'id': '9d34af7a-29b4-450a-a5ef-f67c1396b52e',
#    'facility': '121446',
#    'address': '27478',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'villagatan 4 b 1101tr lgh 1101',
#     'zip': '352 40',
#     'position': {'latitude': 56.8779318848921,
#      'longitude': 14.819242799575,
#      'confidence': 1.0}},
#    'medium': 'District heating',
#    'manufacturer': 'ELV',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '12048262',
#    'readIntervalMinutes': 60},
#   {'id': 'e2dfc71d-ac4b-46aa-b344-5e47a6d49f35',
#    'facility': '121449',
#    'address': '39058',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'villagatan 12',
#     'zip': '35240',
#     'position': {'latitude': 56.8779318821068,
#      'longitude': 14.82124283136,
#      'confidence': 1.0}},
#    'medium': 'District heating',
#    'manufacturer': 'ELV',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '12047996',
#    'readIntervalMinutes': 1440},
#   {'id': '5194467b-430f-4042-aaaf-670e5d2df3c0',
#    'facility': '121454',
#    'address': '30434',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'hammerdalsvägen 4',
#     'zip': '352 00',
#     'position': {'latitude': 56.8879320397209,
#      'longitude': 14.7612418568396,
#      'confidence': 1.0}},
#    'medium': 'District heating',
#    'manufacturer': 'LUG',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '167782691',
#    'readIntervalMinutes': 60},
#   {'id': '9eef153d-2557-4c7c-a119-f4a103bbbac0',
#    'facility': '121459',
#    'address': '31160',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'koltrastvägen 2 -6',
#     'zip': 'unknown',
#     'position': {'latitude': 56.8759318413107,
#      'longitude': 14.8502433179648,
#      'confidence': 1.0}},
#    'medium': 'District heating',
#    'manufacturer': 'LUG',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '6014887',
#    'readIntervalMinutes': 60},
#   {'id': '033ce26a-76a2-437d-9709-1400cd0cb34a',
#    'facility': '121620',
#    'address': '25140',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'östregårdsgatan 8',
#     'zip': '352 34',
#     'position': {'latitude': 56.8780976817931,
#      'longitude': 14.8154545069242,
#      'confidence': 0.5}},
#    'medium': 'District heating',
#    'manufacturer': 'LUG',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '6128823',
#    'readIntervalMinutes': 60},
#   {'id': 'fa20ed3e-a586-4cf5-a85f-a365fc5d518b',
#    'facility': '121688',
#    'address': '31260',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'georg lückligs väg 4',
#     'zip': '35252',
#     'position': {'latitude': 56.854931500032,
#      'longitude': 14.830242983895,
#      'confidence': 1.0}},
#    'medium': 'District heating',
#    'manufacturer': 'LUG',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '6014793',
#    'readIntervalMinutes': 60},
#   {'id': 'd2c02b32-5310-4e5d-b86c-1663d00fa34c',
#    'facility': '122024',
#    'address': '41980',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'storgatan 56',
#     'zip': '35236',
#     'position': {'latitude': 56.8789319042252,
#      'longitude': 14.7882422960947,
#      'confidence': 1.0}},
#    'medium': 'District heating',
#    'manufacturer': 'LUG',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '6113379',
#    'readIntervalMinutes': 60},
#   {'id': '8dc67bd6-0636-4ad3-bad9-efaa9fcee79b',
#    'facility': '122176',
#    'address': '25280',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'södrabogränd 7 -11',
#     'zip': '35251',
#     'position': {'latitude': 56.8600893159556,
#      'longitude': 14.8134524270361,
#      'confidence': 0.0}},
#    'medium': 'District heating',
#    'manufacturer': 'SIE',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '6034540',
#    'readIntervalMinutes': 60},
#   {'id': 'f332e41a-abf5-4c00-85ae-141cda41e502',
#    'facility': '122225',
#    'address': '26198',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'vilhelm mobergs gata 4',
#     'zip': '35234',
#     'position': {'latitude': 56.8759318509772,
#      'longitude': 14.8082426262323,
#      'confidence': 1.0}},
#    'medium': 'District heating',
#    'manufacturer': 'LUG',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '6004091',
#    'readIntervalMinutes': 60},
#   {'id': '580be3b4-e9c8-48ad-8b86-6326dbe34926',
#    'facility': '122246',
#    'address': '24662',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'verkstadsgatan 7',
#     'zip': '352 46'},
#    'medium': 'District heating',
#    'manufacturer': 'LUG',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '6128885',
#    'readIntervalMinutes': 60},
#   {'id': '55e0d347-a26d-4589-9787-faf97c89f932',
#    'facility': '122303',
#    'address': '26184',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'storängsgatan 7',
#     'zip': 'unknown',
#     'position': {'latitude': 56.8779318817792,
#      'longitude': 14.7922423675289,
#      'confidence': 1.0}},
#    'medium': 'District heating',
#    'manufacturer': 'LUG',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '6009527',
#    'readIntervalMinutes': 60},
#   {'id': '98be2950-9f24-4b68-855b-0843778a053a',
#    'facility': '122316',
#    'address': '30073',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'telestadsgatan 18',
#     'zip': 'unknown',
#     'position': {'latitude': 56.8689317287526,
#      'longitude': 14.8002424935219,
#      'confidence': 1.0}},
#    'medium': 'District heating',
#    'manufacturer': 'ELV',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '12006360',
#    'readIntervalMinutes': 1440},
#   {'id': '54e2bd3b-a873-43b2-8b70-97fbe38da36b',
#    'facility': '122357',
#    'address': '42145',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'staglabergsgatan 5',
#     'zip': '352 34',
#     'position': {'latitude': 56.8771350479318,
#      'longitude': 14.8173413126242,
#      'confidence': 0.5}},
#    'medium': 'District heating',
#    'manufacturer': 'ELV',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '12110220',
#    'readIntervalMinutes': 60},
#   {'id': '9355d190-8c47-4146-91e8-e7cb78a848ee',
#    'facility': '122358',
#    'address': '42156',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'staglabergsgatan 7',
#     'zip': '352 34',
#     'position': {'latitude': 56.8768991492931,
#      'longitude': 14.8175444658242,
#      'confidence': 0.5}},
#    'medium': 'District heating',
#    'manufacturer': 'ELV',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '12110627',
#    'readIntervalMinutes': 60},
#   {'id': 'f8744591-9d41-439b-a438-cc1a56457eb3',
#    'facility': '122359',
#    'address': '42707',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'staglabergsgatan 9',
#     'zip': '352 34',
#     'position': {'latitude': 56.8766632182931,
#      'longitude': 14.8177475769242,
#      'confidence': 0.5}},
#    'medium': 'District heating',
#    'manufacturer': 'LUG',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '6024091',
#    'readIntervalMinutes': 60},
#   {'id': 'f9c96bf7-4690-4d9d-ab30-3f9048d6a5ce',
#    'facility': '122361',
#    'address': '38724',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'gelbogatan 8',
#     'zip': '35234',
#     'position': {'latitude': 56.8769318639206,
#      'longitude': 14.8162427569766,
#      'confidence': 1.0}},
#    'medium': 'District heating',
#    'manufacturer': 'ELV',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '12038483',
#    'readIntervalMinutes': 1440},
#   {'id': '86a773a1-a5c4-4f3e-b3dd-6402f070f5b8',
#    'facility': '122362',
#    'address': '42352',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'staglabergsgatan 12 a',
#     'zip': '352 34',
#     'position': {'latitude': 56.876931865559,
#      'longitude': 14.8173242766643,
#      'confidence': 0.0}},
#    'medium': 'District heating',
#    'manufacturer': 'ELV',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '12122869',
#    'readIntervalMinutes': 60},
#   {'id': '1334e6c0-5694-4915-b25b-7df7e2da44d5',
#    'facility': '122363',
#    'address': '30177',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'staglabergsgatan 10',
#     'zip': 'unknown',
#     'position': {'latitude': 56.8769318708019,
#      'longitude': 14.8172427641856,
#      'confidence': 1.0}},
#    'medium': 'District heating',
#    'manufacturer': 'LUG',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '6000587',
#    'readIntervalMinutes': 60},
#   {'id': 'f5b7b169-bc83-43ca-b9e3-1c4f13fde141',
#    'facility': '122364',
#    'address': '29406',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'gelbogatan 12',
#     'zip': 'unknown',
#     'position': {'latitude': 56.8769318576947,
#      'longitude': 14.8162427499315,
#      'confidence': 1.0}},
#    'medium': 'District heating',
#    'manufacturer': 'ELV',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '12006491',
#    'readIntervalMinutes': 1440},
#   {'id': '4ea3a3f2-b936-4e91-bda4-9aebb2e89b3b',
#    'facility': '122366',
#    'address': '30190',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'staglabergsgatan 15',
#     'zip': 'unknown',
#     'position': {'latitude': 56.8759318555648,
#      'longitude': 14.818242782208,
#      'confidence': 1.0}},
#    'medium': 'District heating',
#    'manufacturer': 'LUG',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '6015220',
#    'readIntervalMinutes': 60},
#   {'id': '3fe542f6-62bc-42e5-afbd-7059bb7e490a',
#    'facility': '122472',
#    'address': '42571',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'rådmansgatan 9',
#     'zip': 'unknown',
#     'position': {'latitude': 56.8819319533772,
#      'longitude': 14.7902423201792,
#      'confidence': 1.0}},
#    'medium': 'District heating',
#    'manufacturer': 'ELV',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '12133384',
#    'readIntervalMinutes': 60},
#   {'id': '9afe2323-f734-4f4f-ab0e-894801efbad7',
#    'facility': '122473',
#    'address': '42587',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'vikingagatan 1',
#     'zip': 'unknown',
#     'position': {'latitude': 56.8779318765363,
#      'longitude': 14.7902423229644,
#      'confidence': 1.0}},
#    'medium': 'District heating',
#    'manufacturer': 'ELV',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '12110505',
#    'readIntervalMinutes': 60},
#   {'id': '6aa71611-0ef9-48fd-929b-d6a7765c421e',
#    'facility': '122474',
#    'address': '40747',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'riddaregatan 30',
#     'zip': 'unknown',
#     'position': {'latitude': 56.879931910615,
#      'longitude': 14.786242268078,
#      'confidence': 1.0}},
#    'medium': 'District heating',
#    'manufacturer': 'ELV',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '12133562',
#    'readIntervalMinutes': 60},
#   {'id': '28dfbc01-9693-4460-a816-8a0f1f54c508',
#    'facility': '122475',
#    'address': '42533',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'riddaregatan 32',
#     'zip': 'unknown',
#     'position': {'latitude': 56.8799319145472,
#      'longitude': 14.7862422682419,
#      'confidence': 1.0}},
#    'medium': 'District heating',
#    'manufacturer': 'ELV',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '12133367',
#    'readIntervalMinutes': 60},
#   {'id': '584c9af3-0c5b-4e9e-85c5-fb0dd8ba32fc',
#    'facility': '122476',
#    'address': '42549',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'riddaregatan 34',
#     'zip': 'unknown',
#     'position': {'latitude': 56.8798931918643,
#      'longitude': 14.7862422672588,
#      'confidence': 1.0}},
#    'medium': 'District heating',
#    'manufacturer': 'ELV',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '12133319',
#    'readIntervalMinutes': 60},
#   {'id': '85d675b1-50e8-4e48-814e-1b635df3760c',
#    'facility': '122477',
#    'address': '42530',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'riddaregatan 61',
#     'zip': 'unknown',
#     'position': {'latitude': 56.8829319584563,
#      'longitude': 14.7852422495641,
#      'confidence': 1.0}},
#    'medium': 'District heating',
#    'manufacturer': 'ELV',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '12133348',
#    'readIntervalMinutes': 60},
#   {'id': '511ac305-f7fa-4038-97ab-b9097148ab0f',
#    'facility': '122478',
#    'address': '42599',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'riddaregatan 57',
#     'zip': 'unknown'},
#    'medium': 'District heating',
#    'manufacturer': 'ELV',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '12133401',
#    'readIntervalMinutes': 60},
#   {'id': '4af068bf-5580-49b3-bb37-69316ad60511',
#    'facility': '122479',
#    'address': '42528',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'riddaregatan 55',
#     'zip': '35236',
#     'position': {'latitude': 56.881931947479,
#      'longitude': 14.7852422512025,
#      'confidence': 1.0}},
#    'medium': 'District heating',
#    'manufacturer': 'ELV',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '12133317',
#    'readIntervalMinutes': 60},
#   {'id': '9ea4db95-57c6-4be5-8ef7-eabe5fcfaa84',
#    'facility': '122480',
#    'address': '29459',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'riddaregatan 53',
#     'zip': 'unknown',
#     'position': {'latitude': 56.8819319438745,
#      'longitude': 14.7852422523494,
#      'confidence': 1.0}},
#    'medium': 'District heating',
#    'manufacturer': 'ELV',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '12113022',
#    'readIntervalMinutes': 60},
#   {'id': '7c1570ed-370f-4785-bf03-ece4d9d72231',
#    'facility': '122482',
#    'address': '41988',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'arabygatan 22',
#     'zip': '352 36',
#     'position': {'latitude': 56.8810991590931,
#      'longitude': 14.7847643069242,
#      'confidence': 0.5}},
#    'medium': 'District heating',
#    'manufacturer': 'LUG',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '167805688',
#    'readIntervalMinutes': 60},
#   {'id': 'e9bf0700-d533-4310-b918-89d88d7c481c',
#    'facility': '122483',
#    'address': '28213',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'arabygatan 26',
#     'zip': 'unknown',
#     'position': {'latitude': 56.8819319510835,
#      'longitude': 14.7852422397337,
#      'confidence': 1.0}},
#    'medium': 'District heating',
#    'manufacturer': 'ELV',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '12006523',
#    'readIntervalMinutes': 1440},
#   {'id': '8c6c6772-6564-482a-b705-08cb3ea86fba',
#    'facility': '122484',
#    'address': '40223',
#    'location': {'country': 'sverige',
#     'city': 'växjö',
#     'address': 'riddaregatan 47',
#     'zip': '352 36',
#     'position': {'latitude': 56.8805914777931,
#      'longitude': 14.7863756805242,
#      'confidence': 0.5}},
#    'medium': 'District heating',
#    'manufacturer': 'ELV',
#    'isReported': False,
#    'collectionPercentage': 0.0,
#    'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#    'gatewaySerial': '12100975',
#    'readIntervalMinutes': 1440}],
#  'pageable': {'sort': {'unsorted': True, 'sorted': False, 'empty': True},
#   'pageSize': 50,
#   'pageNumber': 0,
#   'offset': 0,
#   'unpaged': False,
#   'paged': True},
#  'last': False,
#  'totalElements': 5156,
#  'totalPages': 104,
#  'sort': {'unsorted': True, 'sorted': False, 'empty': True},
#  'first': True,
#  'number': 0,
#  'numberOfElements': 50,
#  'size': 50,
#  'empty': False}

# %%
client.meter('d77ec9e7-8481-41d8-8489-cd2a583e432e')
# Out:
# {'id': 'd77ec9e7-8481-41d8-8489-cd2a583e432e',
#  'facility': '121428',
#  'address': '40238',
#  'location': {'country': 'sverige',
#   'city': 'växjö',
#   'address': 'regementsgatan 8',
#   'zip': '352 36',
#   'position': {'latitude': 56.8776581827931,
#    'longitude': 14.7922234766242,
#    'confidence': 0.5}},
#  'medium': 'District heating',
#  'manufacturer': 'ELV',
#  'statusChanged': '2018-05-08T12:58:18Z',
#  'eventLog': [{'type': 'statusChange',
#    'name': 'ok',
#    'start': '2018-05-08T12:58:18Z'},
#   {'type': 'newMeter', 'name': '40238', 'start': '2018-04-19T23:00:00Z'}],
#  'created': '2018-04-21T01:28:45Z',
#  'isReported': False,
#  'alarms': [],
#  'readIntervalMinutes': 1440,
#  'organisationId': '0420446f-d32c-46f8-b2ec-8f9a6a1f4aec',
#  'revision': 2,
#  'mbusDeviceType': 4,
#  'gateway': {'id': 'e415bb5a-86e9-46f2-b203-1bc21a9e5000',
#   'productModel': 'CMi2110',
#   'serial': '12101001',
#   'status': {'id': 'ok', 'name': 'ok'},
#   'statusChanged': '2018-05-08T12:58:18Z',
#   'extraInfo': {}}}
